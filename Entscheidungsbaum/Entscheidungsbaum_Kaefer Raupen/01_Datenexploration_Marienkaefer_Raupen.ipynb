# %% [markdown]
# # Wie können Marienkäfer von Raupen unterschieden werden?

# %% [markdown]
# Wir haben zwei **Klassen** von Insekten:
# - <CODE>Marienkäfer</CODE>
# - <CODE>Raupe</CODE>

# %% [markdown]
# <td>
#     <img src="Bilder\marienkaefer.jpg" alt="Drawing" style="width: 300px; float: left;"  hspace=40 />
#     <img src="Bilder\raupe.jpg" alt="Drawing" style="width: 300px; float: left;" hspace=40/>
# </td>

# %% [markdown]
# Die **Merkmale** die man zur Erkennung heranziehen könnte sind vielfältig. Man könnte z. B. Farben, Größe, Fortbewegungsgeschwindigket und vieles mehr anschauen. Da wir aber ein möglichst einfaches Beispiel betrachten wollen schauen wir uns nur folgende Eigenschaften der Insekten an:
# - "Breite"
# - "Länge"

# %% [markdown]
# # Welche **Breiten** und **Längen** sind typisch für Marienkäfer und Raupen?
#
# Beispielhaft können wir uns einmal die Maße eines Marienkäfers anschauen:

# %% [markdown]
# <img src="Bilder/kaefer_messen.png" alt="Käfer messen" style="width: 300px; float: left;" hspace=40/>

# %% [markdown]
# Uns liegt ein Datensatz für 200 Marienkäfer und Raupen vor.

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Aufgabe: Öffne die Datei **[Käfer.csv](Käfer.csv)** mit einem Texteditor und analysiere und beschreibe den Aufbau.*

# %% [markdown]
# # Daten einlesen mit Python

# %% [markdown]
# Auch mithilfe von Python kann dieser Datensatz eingelesen und komfortabel angezeigt werden.

# %% [markdown]
# <div style="background-color: yellow; padding: 5px 20px 20px">
#
# ### Tipps zum Umgang mit diesem Jupyter-Notebook<a class="tocSkip">
# Jede Zelle mit "Code" muss ausgeführt werden. Dies kann man auf zwei Arten machen:
# - Klick auf den oberen **"Run"-Button**
# - Drücke gleichzeitig die Tasten **"Strg"** + **"Enter"**

# %%
# Bibliothek pandas importieren
import pandas as pd

# Textausgabe
print("Gut gemacht!")
# Out:
# Gut gemacht!

# %% [markdown]
# <div style="background-color: yellow; padding: 5px 20px 20px">
#
# **Hintergrundwissen:**
# *pandas* ist eine Programmbibliothek für die Programmiersprache Python, die Hilfsmittel für die Verwaltung von Daten und deren Analyse anbietet. Insbesondere enthält sie Datenstrukturen und Operatoren für den Zugriff auf numerische Tabellen und Zeitreihen.

# %%
# Datensatz einlesen
# Die Datei "Käfer.csv" ist eine Datei, in der Datensätze zeilenweise aufgeführt sind.
# Jede Spalte ist durch ein Semikolon (";") getrennt.

# df_käfer ist eine eigene Variable und steht für "dataframe Käfer"
df_kaefer = pd.read_csv('Kaefer.csv', sep=';')

# zeige den Datensatz "df_käfer" an
display(df_kaefer)
# Out:
#      Breite  Länge       Insekt
# 0      0.48   0.38  Marienkäfer
# 1      0.32   0.74        Raupe
# 2      0.49   0.27  Marienkäfer
# 3      0.58   0.46  Marienkäfer
# 4      0.11   0.58        Raupe
# ..      ...    ...          ...
# 195    0.57   0.37  Marienkäfer
# 196    0.10   0.54        Raupe
# 197    0.39   0.81        Raupe
# 198    0.56   0.29  Marienkäfer
# 199    0.38   0.93        Raupe
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Wie kann ich den gesamten Datensatz ausgeben?

# %%
# Einstellung zur Anzeige aller Datensätze (Zeilen)
pd.set_option('display.max_rows', None)
# Einstellung zur Anzeige aller Spalten
pd.set_option('display.max_columns', None)

# Datensatz ausgeben
display(df_kaefer)
# Out:
#      Breite  Länge       Insekt
# 0      0.48   0.38  Marienkäfer
# 1      0.32   0.74        Raupe
# 2      0.49   0.27  Marienkäfer
# 3      0.58   0.46  Marienkäfer
# 4      0.11   0.58        Raupe
# 5      0.41   0.32  Marienkäfer
# 6      0.32   0.83        Raupe
# 7      0.45   0.31  Marienkäfer
# 8      0.58   0.42  Marienkäfer
# 9      0.37   0.95        Raupe
# 10     0.39   0.25  Marienkäfer
# 11     0.58   0.41  Marienkäfer
# 12     0.20   0.71        Raupe
# 13     0.10   0.21        Raupe
# 14     0.23   0.64        Raupe
# 15     0.27   0.61        Raupe
# 16     0.15   0.79        Raupe
# 17     0.68   0.43  Marienkäfer
# 18     0.46   0.37  Marienkäfer
# 19     0.57   0.39  Marienkäfer
# 20     0.11   0.56        Raupe
# 21     0.68   0.41  Marienkäfer
# 22     0.53   0.26  Marienkäfer
# 23     0.57   0.36  Marienkäfer
# 24     0.16   0.85        Raupe
# 25     0.42   0.26  Marienkäfer
# 26     0.45   0.37  Marienkäfer
# 27     0.11   0.36        Raupe
# 28     0.56   0.42  Marienkäfer
# 29     0.21   0.89        Raupe
# 30     0.65   0.53  Marienkäfer
# 31     0.42   0.23  Marienkäfer
# 32     0.34   0.68        Raupe
# 33     0.46   0.26  Marienkäfer
# 34     0.31   0.84        Raupe
# 35     0.39   0.93        Raupe
# 36     0.19   0.86        Raupe
# 37     0.21   0.71        Raupe
# 38     0.44   0.34  Marienkäfer
# 39     0.60   0.42  Marienkäfer
# 40     0.65   0.51  Marienkäfer
# 41     0.42   0.27  Marienkäfer
# 42     0.69   0.42  Marienkäfer
# 43     0.32   0.71        Raupe
# 44     0.20   0.74        Raupe
# 45     0.27   0.69        Raupe
# 46     0.29   0.72        Raupe
# 47     0.37   0.79        Raupe
# 48     0.33   0.87        Raupe
# 49     0.18   0.68        Raupe
# 50     0.65   0.41  Marienkäfer
# 51     0.20   0.66        Raupe
# 52     0.41   0.34  Marienkäfer
# 53     0.61   0.35  Marienkäfer
# 54     0.15   0.94        Raupe
# 55     0.19   0.54        Raupe
# 56     0.10   0.25        Raupe
# 57     0.35   0.71        Raupe
# 58     0.39   0.78        Raupe
# 59     0.34   0.74        Raupe
# 60     0.39   0.27  Marienkäfer
# 61     0.34   0.71        Raupe
# 62     0.14   0.41        Raupe
# 63     0.27   0.67        Raupe
# 64     0.25   0.95        Raupe
# 65     0.43   0.33  Marienkäfer
# 66     0.54   0.34  Marienkäfer
# 67     0.37   0.20  Marienkäfer
# 68     0.26   0.81        Raupe
# 69     0.14   0.82        Raupe
# 70     0.25   0.96        Raupe
# 71     0.59   0.41  Marienkäfer
# 72     0.60   0.36  Marienkäfer
# 73     0.34   0.74        Raupe
# 74     0.50   0.38  Marienkäfer
# 75     0.39   0.26  Marienkäfer
# 76     0.67   0.35  Marienkäfer
# 77     0.59   0.43  Marienkäfer
# 78     0.65   0.47  Marienkäfer
# 79     0.38   0.88        Raupe
# 80     0.13   0.49        Raupe
# 81     0.43   0.25  Marienkäfer
# 82     0.23   0.57        Raupe
# 83     0.32   0.97        Raupe
# 84     0.19   0.85        Raupe
# 85     0.35   0.89        Raupe
# 86     0.21   0.69        Raupe
# 87     0.68   0.36  Marienkäfer
# 88     0.51   0.25  Marienkäfer
# 89     0.61   0.42  Marienkäfer
# 90     0.21   0.60        Raupe
# 91     0.16   0.85        Raupe
# 92     0.32   0.82        Raupe
# 93     0.39   0.89        Raupe
# 94     0.38   0.82        Raupe
# 95     0.10   0.45        Raupe
# 96     0.27   0.86        Raupe
# 97     0.17   0.37        Raupe
# 98     0.57   0.30  Marienkäfer
# 99     0.26   0.87        Raupe
# 100    0.60   0.47  Marienkäfer
# 101    0.37   0.88        Raupe
# 102    0.58   0.39  Marienkäfer
# 103    0.51   0.33  Marienkäfer
# 104    0.51   0.27  Marienkäfer
# 105    0.33   0.85        Raupe
# 106    0.59   0.29  Marienkäfer
# 107    0.40   0.23  Marienkäfer
# 108    0.46   0.25  Marienkäfer
# 109    0.50   0.29  Marienkäfer
# 110    0.20   0.92        Raupe
# 111    0.53   0.27  Marienkäfer
# 112    0.33   0.93        Raupe
# 113    0.47   0.32  Marienkäfer
# 114    0.65   0.50  Marienkäfer
# 115    0.63   0.40  Marienkäfer
# 116    0.46   0.28  Marienkäfer
# 117    0.36   0.74        Raupe
# 118    0.50   0.27  Marienkäfer
# 119    0.66   0.37  Marienkäfer
# 120    0.37   0.26  Marienkäfer
# 121    0.39   0.79        Raupe
# 122    0.32   0.68        Raupe
# 123    0.19   0.52        Raupe
# 124    0.38   0.27  Marienkäfer
# 125    0.34   0.69        Raupe
# 126    0.67   0.38  Marienkäfer
# 127    0.39   0.23  Marienkäfer
# 128    0.19   0.78        Raupe
# 129    0.60   0.42  Marienkäfer
# 130    0.19   0.95        Raupe
# 131    0.66   0.39  Marienkäfer
# 132    0.67   0.33  Marienkäfer
# 133    0.57   0.37  Marienkäfer
# 134    0.16   0.51        Raupe
# 135    0.51   0.28  Marienkäfer
# 136    0.38   0.89        Raupe
# 137    0.59   0.30  Marienkäfer
# 138    0.37   0.22  Marienkäfer
# 139    0.40   0.20  Marienkäfer
# 140    0.35   0.24  Marienkäfer
# 141    0.14   0.71        Raupe
# 142    0.47   0.30  Marienkäfer
# 143    0.35   0.91        Raupe
# 144    0.31   0.69        Raupe
# 145    0.31   0.81        Raupe
# 146    0.39   0.88        Raupe
# 147    0.38   0.22  Marienkäfer
# 148    0.13   0.47        Raupe
# 149    0.32   0.84        Raupe
# 150    0.37   0.26  Marienkäfer
# 151    0.10   0.91        Raupe
# 152    0.38   0.27  Marienkäfer
# 153    0.36   0.85        Raupe
# 154    0.12   0.83        Raupe
# 155    0.69   0.48  Marienkäfer
# 156    0.59   0.47  Marienkäfer
# 157    0.60   0.30  Marienkäfer
# 158    0.36   0.79        Raupe
# 159    0.17   0.62        Raupe
# 160    0.23   0.82        Raupe
# 161    0.15   0.41        Raupe
# 162    0.66   0.49  Marienkäfer
# 163    0.64   0.51  Marienkäfer
# 164    0.21   0.56        Raupe
# 165    0.38   0.29  Marienkäfer
# 166    0.30   0.96        Raupe
# 167    0.39   0.26  Marienkäfer
# 168    0.58   0.31  Marienkäfer
# 169    0.55   0.41  Marienkäfer
# 170    0.61   0.51  Marienkäfer
# 171    0.59   0.44  Marienkäfer
# 172    0.19   0.49        Raupe
# 173    0.16   0.40        Raupe
# 174    0.25   0.55        Raupe
# 175    0.32   0.75        Raupe
# 176    0.56   0.34  Marienkäfer
# 177    0.46   0.24  Marienkäfer
# 178    0.20   0.69        Raupe
# 179    0.35   0.23  Marienkäfer
# 180    0.39   0.21  Marienkäfer
# 181    0.22   0.58        Raupe
# 182    0.68   0.50  Marienkäfer
# 183    0.23   0.52        Raupe
# 184    0.13   0.26        Raupe
# 185    0.54   0.34  Marienkäfer
# 186    0.19   0.91        Raupe
# 187    0.31   0.69        Raupe
# 188    0.53   0.40  Marienkäfer
# 189    0.64   0.46  Marienkäfer
# 190    0.35   0.23  Marienkäfer
# 191    0.42   0.21  Marienkäfer
# 192    0.35   0.74        Raupe
# 193    0.23   0.62        Raupe
# 194    0.65   0.51  Marienkäfer
# 195    0.57   0.37  Marienkäfer
# 196    0.10   0.54        Raupe
# 197    0.39   0.81        Raupe
# 198    0.56   0.29  Marienkäfer
# 199    0.38   0.93        Raupe

# %% [markdown]
# ## Wie kann ich den Datensatz sortieren?

# %%
# sortiere die Datensätze nach einer Spalte (aufsteigend) mit Ausgabe
sortInsekt = df_kaefer.sort_values(by='Insekt')
display(sortInsekt)
# Out:
#      Breite  Länge       Insekt
# 0      0.48   0.38  Marienkäfer
# 147    0.38   0.22  Marienkäfer
# 150    0.37   0.26  Marienkäfer
# 89     0.61   0.42  Marienkäfer
# 88     0.51   0.25  Marienkäfer
# 87     0.68   0.36  Marienkäfer
# 152    0.38   0.27  Marienkäfer
# 155    0.69   0.48  Marienkäfer
# 81     0.43   0.25  Marienkäfer
# 156    0.59   0.47  Marienkäfer
# 157    0.60   0.30  Marienkäfer
# 78     0.65   0.47  Marienkäfer
# 98     0.57   0.30  Marienkäfer
# 77     0.59   0.43  Marienkäfer
# 75     0.39   0.26  Marienkäfer
# 74     0.50   0.38  Marienkäfer
# 72     0.60   0.36  Marienkäfer
# 71     0.59   0.41  Marienkäfer
# 67     0.37   0.20  Marienkäfer
# 66     0.54   0.34  Marienkäfer
# 132    0.67   0.33  Marienkäfer
# 162    0.66   0.49  Marienkäfer
# 163    0.64   0.51  Marienkäfer
# 165    0.38   0.29  Marienkäfer
# 60     0.39   0.27  Marienkäfer
# 76     0.67   0.35  Marienkäfer
# 198    0.56   0.29  Marienkäfer
# 100    0.60   0.47  Marienkäfer
# 142    0.47   0.30  Marienkäfer
# 129    0.60   0.42  Marienkäfer
# 133    0.57   0.37  Marienkäfer
# 127    0.39   0.23  Marienkäfer
# 126    0.67   0.38  Marienkäfer
# 124    0.38   0.27  Marienkäfer
# 135    0.51   0.28  Marienkäfer
# 137    0.59   0.30  Marienkäfer
# 120    0.37   0.26  Marienkäfer
# 119    0.66   0.37  Marienkäfer
# 118    0.50   0.27  Marienkäfer
# 138    0.37   0.22  Marienkäfer
# 116    0.46   0.28  Marienkäfer
# 115    0.63   0.40  Marienkäfer
# 114    0.65   0.50  Marienkäfer
# 113    0.47   0.32  Marienkäfer
# 139    0.40   0.20  Marienkäfer
# 111    0.53   0.27  Marienkäfer
# 140    0.35   0.24  Marienkäfer
# 109    0.50   0.29  Marienkäfer
# 108    0.46   0.25  Marienkäfer
# 107    0.40   0.23  Marienkäfer
# 106    0.59   0.29  Marienkäfer
# 104    0.51   0.27  Marienkäfer
# 103    0.51   0.33  Marienkäfer
# 102    0.58   0.39  Marienkäfer
# 167    0.39   0.26  Marienkäfer
# 168    0.58   0.31  Marienkäfer
# 65     0.43   0.33  Marienkäfer
# 170    0.61   0.51  Marienkäfer
# 30     0.65   0.53  Marienkäfer
# 169    0.55   0.41  Marienkäfer
# 185    0.54   0.34  Marienkäfer
# 28     0.56   0.42  Marienkäfer
# 26     0.45   0.37  Marienkäfer
# 25     0.42   0.26  Marienkäfer
# 23     0.57   0.36  Marienkäfer
# 22     0.53   0.26  Marienkäfer
# 21     0.68   0.41  Marienkäfer
# 188    0.53   0.40  Marienkäfer
# 19     0.57   0.39  Marienkäfer
# 18     0.46   0.37  Marienkäfer
# 17     0.68   0.43  Marienkäfer
# 189    0.64   0.46  Marienkäfer
# 190    0.35   0.23  Marienkäfer
# 191    0.42   0.21  Marienkäfer
# 11     0.58   0.41  Marienkäfer
# 10     0.39   0.25  Marienkäfer
# 194    0.65   0.51  Marienkäfer
# 8      0.58   0.42  Marienkäfer
# 7      0.45   0.31  Marienkäfer
# 195    0.57   0.37  Marienkäfer
# 5      0.41   0.32  Marienkäfer
# 3      0.58   0.46  Marienkäfer
# 2      0.49   0.27  Marienkäfer
# 31     0.42   0.23  Marienkäfer
# 33     0.46   0.26  Marienkäfer
# 131    0.66   0.39  Marienkäfer
# 39     0.60   0.42  Marienkäfer
# 50     0.65   0.41  Marienkäfer
# 38     0.44   0.34  Marienkäfer
# 42     0.69   0.42  Marienkäfer
# 179    0.35   0.23  Marienkäfer
# 40     0.65   0.51  Marienkäfer
# 52     0.41   0.34  Marienkäfer
# 180    0.39   0.21  Marienkäfer
# 182    0.68   0.50  Marienkäfer
# 177    0.46   0.24  Marienkäfer
# 171    0.59   0.44  Marienkäfer
# 176    0.56   0.34  Marienkäfer
# 53     0.61   0.35  Marienkäfer
# 41     0.42   0.27  Marienkäfer
# 193    0.23   0.62        Raupe
# 174    0.25   0.55        Raupe
# 173    0.16   0.40        Raupe
# 151    0.10   0.91        Raupe
# 172    0.19   0.49        Raupe
# 164    0.21   0.56        Raupe
# 136    0.38   0.89        Raupe
# 134    0.16   0.51        Raupe
# 196    0.10   0.54        Raupe
# 166    0.30   0.96        Raupe
# 197    0.39   0.81        Raupe
# 192    0.35   0.74        Raupe
# 175    0.32   0.75        Raupe
# 158    0.36   0.79        Raupe
# 160    0.23   0.82        Raupe
# 183    0.23   0.52        Raupe
# 153    0.36   0.85        Raupe
# 184    0.13   0.26        Raupe
# 154    0.12   0.83        Raupe
# 149    0.32   0.84        Raupe
# 148    0.13   0.47        Raupe
# 181    0.22   0.58        Raupe
# 145    0.31   0.81        Raupe
# 144    0.31   0.69        Raupe
# 143    0.35   0.91        Raupe
# 186    0.19   0.91        Raupe
# 187    0.31   0.69        Raupe
# 141    0.14   0.71        Raupe
# 178    0.20   0.69        Raupe
# 159    0.17   0.62        Raupe
# 161    0.15   0.41        Raupe
# 146    0.39   0.88        Raupe
# 99     0.26   0.87        Raupe
# 128    0.19   0.78        Raupe
# 57     0.35   0.71        Raupe
# 56     0.10   0.25        Raupe
# 55     0.19   0.54        Raupe
# 54     0.15   0.94        Raupe
# 51     0.20   0.66        Raupe
# 49     0.18   0.68        Raupe
# 48     0.33   0.87        Raupe
# 47     0.37   0.79        Raupe
# 46     0.29   0.72        Raupe
# 45     0.27   0.69        Raupe
# 44     0.20   0.74        Raupe
# 43     0.32   0.71        Raupe
# 37     0.21   0.71        Raupe
# 36     0.19   0.86        Raupe
# 58     0.39   0.78        Raupe
# 35     0.39   0.93        Raupe
# 32     0.34   0.68        Raupe
# 29     0.21   0.89        Raupe
# 27     0.11   0.36        Raupe
# 24     0.16   0.85        Raupe
# 20     0.11   0.56        Raupe
# 16     0.15   0.79        Raupe
# 15     0.27   0.61        Raupe
# 14     0.23   0.64        Raupe
# 13     0.10   0.21        Raupe
# 12     0.20   0.71        Raupe
# 9      0.37   0.95        Raupe
# 6      0.32   0.83        Raupe
# 4      0.11   0.58        Raupe
# 1      0.32   0.74        Raupe
# 34     0.31   0.84        Raupe
# 130    0.19   0.95        Raupe
# 59     0.34   0.74        Raupe
# 62     0.14   0.41        Raupe
# 125    0.34   0.69        Raupe
# 123    0.19   0.52        Raupe
# 122    0.32   0.68        Raupe
# 121    0.39   0.79        Raupe
# 117    0.36   0.74        Raupe
# 112    0.33   0.93        Raupe
# 110    0.20   0.92        Raupe
# 105    0.33   0.85        Raupe
# 101    0.37   0.88        Raupe
# 97     0.17   0.37        Raupe
# 96     0.27   0.86        Raupe
# 95     0.10   0.45        Raupe
# 94     0.38   0.82        Raupe
# 93     0.39   0.89        Raupe
# 61     0.34   0.71        Raupe
# 92     0.32   0.82        Raupe
# 90     0.21   0.60        Raupe
# 86     0.21   0.69        Raupe
# 85     0.35   0.89        Raupe
# 84     0.19   0.85        Raupe
# 83     0.32   0.97        Raupe
# 82     0.23   0.57        Raupe
# 80     0.13   0.49        Raupe
# 79     0.38   0.88        Raupe
# 73     0.34   0.74        Raupe
# 70     0.25   0.96        Raupe
# 69     0.14   0.82        Raupe
# 68     0.26   0.81        Raupe
# 64     0.25   0.95        Raupe
# 63     0.27   0.67        Raupe
# 91     0.16   0.85        Raupe
# 199    0.38   0.93        Raupe

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Aufgabe: Sortiere die Datensätze nach der **Breite** und lasse Dir alle Datensätze ausgeben.*

# %%
# bitte füge Deine Lösung als Quelltext hier ein

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Aufgabe: Sortiere die Datensätze nach der Länge und lasse Dir alle Datensätze ausgeben.*

# %%
# bitte füge Deine Lösung als Quelltext hier ein

# %% [markdown]
# # Streudiagramm
#
# Im Folgenden ist ein Streudiagramm dargestellt.

# %% [markdown]
# <img src="Bilder/Beispieldiagramm_Marienkaefer_Raupe.png" alt="Streudiagramm" style="float: left;">

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Aufgabe: Beschreibe, welche Informationen durch das Streudiagramm dargestellt werden.*

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Aufgabe: Erläutere, wie groß die im Streudiagramm dargestellten Insekten sind.*

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Aufgabe: *Erstelle ein Streudiagramm auf Papier und trage die Daten von folgenden Marienkäfern und Raupen ein.*
#
# Zeilennr. | Breite | Länge | Insekt
# --------- | ------ | ------| ------
# 0         | 0.48   | 0.38  | Marienkäfer
# 1         | 0.32   | 0.74  | Raupe
# 2         | 0.49   | 0.27  | Marienkäfer
# 3         | 0.58   | 0.46  | Marienkäfer
# 4         | 0.11   | 0.58  | Raupe

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Aufgabe: Trage die folgenden Insekten zusätzlich in Dein Streudiagramm ein und bestimme - auf Grundlage ihrer Größe (Breite|Länge) - begründet ihre Insektenklasse (Marienkäfer oder Raupe):*
#
# Insekt | Breite | Länge
# ------------------ | ------ | ------
# Insekt a           | 0.6    | 0.4
# Insekt b           | 0.2    | 0.8
# Insekt c           | 0.8    | 0.4
# Insekt d           | 0.5    | 0.6

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Aufgabe: Beurteile jeweils, wie zuverlässig Deine Vorhersage für die Insekten a - d ist.*

# %% [markdown]
# # Vertiefung für die Schnellen
#
# Im Folgenden wird das Streudiagramm mit den 100 Marienkäfern und 100 Raupen dargestellt.
# Bitte folgende Code-Zellen ausführen.

# %%
# Dieser Quelltext ist nicht prüfungsrelevant.

#Bibliotheken plotly und cufflinks zur Datenvisualisierung importieren
from plotly.offline import iplot
import plotly.graph_objects as go
import cufflinks as cf
from ipywidgets import interactive
from PyTree import ClassificationTree as ct
cf.go_offline()


#Ein quadratsiches Layout für plotly-Graphiken wird definiert 
square_layout = go.Layout(xaxis={'title':'Breite','range':[-0.01,1.01]},
                   yaxis={'title':'Länge','range':[-0.01,1.01]},
                   height=600,
                   width=600)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Entscheidungsbaum initialisieren mit Zielvariable (hier in Spalte "Insekt") und Trainingsdaten
tree1 = ct.DecisionTree(target = 'Insekt', data = df_kaefer)

# Entscheidungsbaum erstellen 

# threshold bedeutet Schwellenwert

s_wert = 0.3
tree1.manual_split(attribute = 'Länge',  threshold = s_wert, node_nr = 1)

fehlersumme_raupe = tree1.get_target_distribution(node_nr = 2)['Raupe'] 
fehlersumme_kaefer = tree1.get_target_distribution(node_nr = 3)['Marienkäfer'] 
fehlersumme = fehlersumme_raupe + fehlersumme_kaefer
print("Fehlersumme =", fehlersumme)

#Entscheidungsbaum ausgeben
tree1.print_tree()
# Out:
# Fehlersumme = 61

# %%
# Dieser Quelltext ist nicht prüfungsrelevant.

df_kaefer.iplot('scatter', mode = 'markers',  layout = square_layout,
               x = 'Breite',
               y = 'Länge',
               categories = 'Insekt',
               hline=0.54)
# Out:
# <div>                            <div id="ad283b1f-87a1-4d22-8b6e-08ea7dc18e9b" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ad283b1f-87a1-4d22-8b6e-08ea7dc18e9b")) {                    Plotly.newPlot(                        "ad283b1f-87a1-4d22-8b6e-08ea7dc18e9b",                        [{"marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"width":1.3},"opacity":0.8,"size":12,"symbol":"circle"},"mode":"markers","name":"Marienk\u00e4fer","textfont":{"color":"#4D5663"},"type":"scatter","x":[0.48,0.49,0.58,0.41,0.45,0.58,0.39,0.58,0.68,0.46,0.57,0.68,0.53,0.57,0.42,0.45,0.56,0.65,0.42,0.46,0.44,0.6,0.65,0.42,0.69,0.65,0.41,0.61,0.39,0.43,0.54,0.37,0.59,0.6,0.5,0.39,0.67,0.59,0.65,0.43,0.68,0.51,0.61,0.57,0.6,0.58,0.51,0.51,0.59,0.4,0.46,0.5,0.53,0.47,0.65,0.63,0.46,0.5,0.66,0.37,0.38,0.67,0.39,0.6,0.66,0.67,0.57,0.51,0.59,0.37,0.4,0.35,0.47,0.38,0.37,0.38,0.69,0.59,0.6,0.66,0.64,0.38,0.39,0.58,0.55,0.61,0.59,0.56,0.46,0.35,0.39,0.68,0.54,0.53,0.64,0.35,0.42,0.65,0.57,0.56],"y":[0.38,0.27,0.46,0.32,0.31,0.42,0.25,0.41,0.43,0.37,0.39,0.41,0.26,0.36,0.26,0.37,0.42,0.53,0.23,0.26,0.34,0.42,0.51,0.27,0.42,0.41,0.34,0.35,0.27,0.33,0.34,0.2,0.41,0.36,0.38,0.26,0.35,0.43,0.47,0.25,0.36,0.25,0.42,0.3,0.47,0.39,0.33,0.27,0.29,0.23,0.25,0.29,0.27,0.32,0.5,0.4,0.28,0.27,0.37,0.26,0.27,0.38,0.23,0.42,0.39,0.33,0.37,0.28,0.3,0.22,0.2,0.24,0.3,0.22,0.26,0.27,0.48,0.47,0.3,0.49,0.51,0.29,0.26,0.31,0.41,0.51,0.44,0.34,0.24,0.23,0.21,0.5,0.34,0.4,0.46,0.23,0.21,0.51,0.37,0.29]},{"marker":{"color":"rgba(55, 128, 191, 1.0)","line":{"width":1.3},"opacity":0.8,"size":12,"symbol":"circle"},"mode":"markers","name":"Raupe","textfont":{"color":"#4D5663"},"type":"scatter","x":[0.32,0.11,0.32,0.37,0.2,0.1,0.23,0.27,0.15,0.11,0.16,0.11,0.21,0.34,0.31,0.39,0.19,0.21,0.32,0.2,0.27,0.29,0.37,0.33,0.18,0.2,0.15,0.19,0.1,0.35,0.39,0.34,0.34,0.14,0.27,0.25,0.26,0.14,0.25,0.34,0.38,0.13,0.23,0.32,0.19,0.35,0.21,0.21,0.16,0.32,0.39,0.38,0.1,0.27,0.17,0.26,0.37,0.33,0.2,0.33,0.36,0.39,0.32,0.19,0.34,0.19,0.19,0.16,0.38,0.14,0.35,0.31,0.31,0.39,0.13,0.32,0.1,0.36,0.12,0.36,0.17,0.23,0.15,0.21,0.3,0.19,0.16,0.25,0.32,0.2,0.22,0.23,0.13,0.19,0.31,0.35,0.23,0.1,0.39,0.38],"y":[0.74,0.58,0.83,0.95,0.71,0.21,0.64,0.61,0.79,0.56,0.85,0.36,0.89,0.68,0.84,0.93,0.86,0.71,0.71,0.74,0.69,0.72,0.79,0.87,0.68,0.66,0.94,0.54,0.25,0.71,0.78,0.74,0.71,0.41,0.67,0.95,0.81,0.82,0.96,0.74,0.88,0.49,0.57,0.97,0.85,0.89,0.69,0.6,0.85,0.82,0.89,0.82,0.45,0.86,0.37,0.87,0.88,0.85,0.92,0.93,0.74,0.79,0.68,0.52,0.69,0.78,0.95,0.51,0.89,0.71,0.91,0.69,0.81,0.88,0.47,0.84,0.91,0.85,0.83,0.79,0.62,0.82,0.41,0.56,0.96,0.49,0.4,0.55,0.75,0.69,0.58,0.52,0.26,0.91,0.69,0.74,0.62,0.54,0.81,0.93]}],                        {"height":600,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...

# %%
# Entscheidungsbaum initialisieren mit Zielvariable (hier in Spalte "Insekt") und Trainingsdaten
tree2 = ct.DecisionTree(target = 'Insekt', data = df_kaefer)

# Entscheidungsbaum mit einer Entscheidungsregel erstellen 

# threshold bedeutet Schwellenwert
def split(Attribut, Schwellenwert):
    tree2.manual_split(attribute = Attribut,  threshold = Schwellenwert, node_nr = 1)                    
    display(tree2.print_tree())                    
    
tree_widget = interactive(split,{'manual': True, 'manual_name': 'Erstelle Split'}, 
                          Attribut = ['Länge', 'Breite'], Schwellenwert = (0.0,1.0,0.01)) 

display(tree_widget)

# %% [markdown]
# <div style="background-color: lightblue; padding: 5px 20px 20px">
#
# ## *Vertiefungsaufgabe: Beschreibe, welche Informationen durch das folgende Streudiagramm dargestellt werden.*
